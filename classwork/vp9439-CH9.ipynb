# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

plt.plot(X, Y, 'b.')
plt.plot(X, m*X + c, 'r-')
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
X = np.random.rand(5)*10
X = np.sort(X)
Y = np.random.rand(5)*10
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

plt.plot(X, Y, 'b.')
plt.plot(X, m*X + c, 'r-')
plt.show()
# Out:
# Slope: 0.8491283663902213, Intercept: -3.31033325414256

# %%
X = np.arange(0,1,0.01)
Y = 0.5*X + 3
error = np.random.rand(len(X))*2-1
y = Y + error

A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, y, rcond=None)[0]

residuals = y - (m*X + c)
max_index = np.argmax(np.abs(residuals))
min_index = np.argmin(np.abs(residuals))
    
print(f"Slope: {m}, Intercept: {c}")
print(f"Residuals:\n{residuals}")
print(f"Maximum Residual: {residuals[max_index]} at ({X[max_index]},{y[max_index]})")
print(f"Minimum Residual: {residuals[min_index]} at ({X[min_index]},{y[min_index]})")

plt.plot(X,Y,'r-', label = 'Original Equation')
plt.plot(X, y, 'b.')
plt.plot(X, m*X + c, 'g-', label = 'Best Fit Line')
plt.legend()
plt.show()
# Out:
# Slope: 0.493752026381845, Intercept: 2.938247651753647
# Residuals:
# [-0.48287346  0.08771281  0.13828045 -0.31602678  0.84949028 -0.91917324
#   1.04250314  0.08427276 -0.05984123 -0.55501787 -0.88301098  0.08589976
#   0.44700649  0.34899889 -0.23502587  0.05125303 -0.34161513 -0.75571712
#  -0.25268223  0.73060557  0.52974986 -0.48146286  0.30710096  0.55253036
#  -0.86836681  0.35560853  0.22178014  0.36906197  0.91719964  0.34141948
#   0.56218264  0.30713269 -0.40338448 -0.78822007 -0.23381785 -0.19083531
#  -0.31208407 -0.80348234 -0.60083106  0.50126909  0.16224068 -0.24431268
#  -0.51211515  0.16411264 -0.70539923  0.92236752  0.20054323 -0.75014104
#  -0.00284914 -0.62948018 -0.38708047 -0.43095895  0.87912358 -0.02008732
#  -0.65174563  0.64603299  0.92910162 -0.58635182  0.51001953  0.91670091
#  -0.32217771 -0.2787831   0.27210611  0.13822489 -0.91464038 -0.02503443
#   0.41551382 -0.25627827  0.93427246  1.03782466  0.06071694  0.54915669
#  -0.75504315 -0.81120309  0.95724027 -0.15892823 -0.57117506  0.57738121
#   0.14449815 -0.55829401  0.54796275  0.12303888  0.59380976  0.69609205
#   0.46261767 -0.8248274   0.05855774  0.58996508 -0.10146742  0.2981394
#   0.63462362 -0.55610639 -0.27682013 -0.52671238 -0.06955019 -0.10091179
#  -0.33961172 -0.66746529 -0.41669753 -0.31732535]
# Maximum Residual: 1.0425031370172806 at (0.06,4.010375910353838)
# Minimum Residual: -0.0028491413761853046 at (0.48,3.1723994830407474)
