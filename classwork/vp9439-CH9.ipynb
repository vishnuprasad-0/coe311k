# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

plt.plot(X, Y, 'b.')
plt.plot(X, m*X + c, 'r-')
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
X = np.random.rand(5)*10
X = np.sort(X)
Y = np.random.rand(5)*10
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

plt.plot(X, Y, 'b.')
plt.plot(X, m*X + c, 'r-')
plt.show()
# Out:
# Slope: 0.8491283663902213, Intercept: -3.31033325414256

# %%
X = np.arange(0,1,0.01)
Y = 0.5*X + 3
error = np.random.rand(len(X))*2-1
y = Y + error

A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, y, rcond=None)[0]

residuals = y - Y
max_index = np.argmax(np.abs(residuals))
min_index = np.argmin(np.abs(residuals))

    
print(f"Slope: {m}, Intercept: {c}")
print(f"Residuals:\n{residuals}")
print(f"Maximum Residual: {residuals[max_index]} at ({X[max_index]},{y[max_index]})")
print(f"Minimum Residual: {residuals[min_index]} at ({X[min_index]},{y[min_index]})")

plt.plot(X,Y,'r-', label = 'Original Equation')
plt.plot(X, y, 'b.')
plt.plot(X, m*X + c, 'g-', label = 'Best Fit Line')
plt.legend()
plt.show()
# Out:
# Slope: 0.2899504615802286, Intercept: 3.049309884653213
# Residuals:
# [ 0.19812821 -0.21395042 -0.29183548 -0.49688359 -0.06310366  0.77762283
#  -0.78161278 -0.48554033 -0.17024205  0.36580893  0.67531402  0.57167729
#   0.87214723 -0.74129496 -0.36616625 -0.25005205 -0.21916222 -0.70786005
#  -0.05910916  0.31831037 -0.63495423  0.28424202 -0.38489957 -0.51088164
#   0.85070448 -0.44628802  0.51690983 -0.1425915  -0.813055    0.87294552
#   0.92798633  0.63171665 -0.2498074  -0.7031873  -0.54660431  0.27495336
#  -0.07939603 -0.49861976  0.96674387 -0.37904785 -0.83123414  0.63987426
#   0.96886069  0.51632844  0.65528835 -0.30545132 -0.70930307  0.83501182
#  -0.29058434  0.86505946  0.23579151  0.39631742 -0.05812559 -0.20808784
#  -0.28827461 -0.56080165 -0.50448802 -0.61451422 -0.47853919  0.13494793
#   0.50190715 -0.59808327  0.3098515   0.40828676 -0.76084236 -0.23589871
#   0.70110164  0.60614102 -0.52367242 -0.931631   -0.89335873  0.00680325
#  -0.47549183  0.17470051  0.93389863  0.08092054 -0.31958646  0.59952955
#  -0.00907164  0.93322357  0.75725373 -0.55981174 -0.74858331 -0.89717051
#   0.22168071 -0.65437806  0.40632961  0.36283579 -0.98378618  0.20113847
#  -0.20028927 -0.36700677 -0.18008522 -0.82585432  0.49585367 -0.70611755
#   0.89562913 -0.8437531  -0.75454891 -0.86166883]
# Maximum Residual: -0.983786182564669 at (0.88,2.456213817435331)
# Minimum Residual: 0.006803250415743367 at (0.71,3.3618032504157433)
