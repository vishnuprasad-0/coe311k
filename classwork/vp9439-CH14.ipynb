# %%
import numpy as np
import matplotlib.pyplot as plt

# Step size
h = (b - a) / (N - 1)
# Central Difference Approximation for the derivative
df_dx_central = (f(x + h) - f(x - h)) / (2 * h)
df_dx_forward = (f(x + h) - f(x)) / h
df_dx_backward = (f(x) - f(x - h)) / h

# Plot the approximation and the true derivative
plt.subplot(2,2,1)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("True Derivative of f(x) = sin(x)")
plt.legend()
plt.show()

plt.subplot(2,2,2)
plt.plot(x, df_dx_central, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()
plt.show()

plt.subplot(2,2,3)
plt.plot(x, df_dx_forward, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()
plt.show()

plt.subplot(2,2,4)
plt.plot(x, df_dx_backward, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()
plt.show()
