# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 50)
plt.subplot(2,2,1)
plt.plot(x, np.tan(x), 'r')
plt.subplot(2,2,2)
plt.scatter(x, np.sin(x), 10, 'b')
plt.subplot(2,2,3)
plt.hist(x, 100)
plt.subplot(2,2,4)
plt.plot(x, np.cos(x), 'y')
plt.show()
