# %%
import numpy as np
import matplotlib.pyplot as plt

x_start, x_end = 0, 2

def defineParameters(h):
    num_steps = int((x_end - x_start) / h)
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    y_values[0] = 1 # y(0) = 1
    return num_steps, x_values, y_values

# Function representing dy/dx = -2y
def f(x, y):
    return -2 * y

def plot(h):
    plt.plot(x_values, y_values, label=f'h = {h:.2f}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f"Approximation of dy/dx = -2y using Euler's Method")
    plt.legend()
    plt.show()

stepSize = np.arange(0.01, 1, 0.05)
for h in stepSize:
    num_steps, x_values, y_values = defineParameters(h)

    # Implement Euler's method
    for i in range(num_steps):
        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])
    
    if h == 0.01:
        x_first = x_values.copy()
        y_first = y_values.copy()
        plot(h)
    else:
        y_interp = np.interp(x_values, x_first, y_first)
        error = np.abs(y_interp - y_values)
        totalError = np.sum(error)
        plot(h)
        print(f'Error: {error}')
        print(f'Total Error: {totalError}')
# Out:
# Error: [0.         0.00476863 0.00841438 0.01113557 0.01309937 0.01444644
#  0.01529476 0.01574313 0.01587395 0.01575579 0.01544546 0.01498986
#  0.01442748 0.01378979 0.01310232 0.01238562 0.0116561  0.01092826
#  0.01021165 0.00951235 0.00883622 0.00818748 0.00756906 0.00698281
#  0.00642971 0.0059101  0.00542373 0.00497    0.00454795 0.00415641
#  0.00379404 0.0034594  0.00315099 0.00286726]
# Total Error: 0.317266079371714
# Error: [0.         0.01895195 0.02992105 0.03543077 0.03729508 0.03680555
#  0.03487111 0.03212206 0.02898716 0.02575063 0.02259889 0.0196348
#  0.01691883 0.01447767 0.01231579 0.01042362 0.00878326 0.0073724
#  0.00616698]
# Total Error: 0.3988276185511421
# Error: [0.         0.03414708 0.04758277 0.04973768 0.04625696 0.04032691
#  0.03375207 0.02747998 0.02191737 0.01720892 0.01335123 0.01025546
#  0.00781317]
# Total Error: 0.34982960701089383
# Error: [0.         0.05832105 0.07104564 0.06495872 0.05283364 0.04032098
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x_start, x_end = 0, 10

def defineParameters(h):
    num_steps = int((x_end - x_start) / h)
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    y_values[0] = 1 # y(0) = 1
    return num_steps, x_values, y_values

# Function representing dy/dx = -2y
def f(x, y):
    return -2 * y

# Exact function
def exactf(x, y):
    return np.exp(-2 * x)

def calcError(x, y):
    y_exact = exactf(x, y)
    localError = y_exact - y
    globalError = np.sum(np.abs(localError))
    return localError, globalError

def plot(h):
    plt.plot(x_values, y_values, label=f'h = {h:.2f}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f"Approximation of dy/dx = -2y using Euler's Method")
    plt.legend()
    plt.show()

stepSize = np.array([.1, .5, 1, 1.5])
for h in stepSize:
    num_steps, x_values, y_values = defineParameters(h)
    
    # Implement Euler's method
    for i in range(num_steps):
        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])
    
    localError, globalError = calcError(x_values, y_values)
    plot(h)
    print(f'Local Error: {localError}')
    print(f'Global Error: {globalError}')
# Out:
# Local Error: [0.00000000e+00 1.87307531e-02 3.03200460e-02 3.68116361e-02
#  3.97289641e-02 4.01994412e-02 3.90502119e-02 3.68817639e-02
#  3.41243580e-02 3.10811602e-02 2.79611008e-02 2.49038124e-02
#  2.19984766e-02 1.92979968e-02 1.68295975e-02 1.46026963e-02
#  1.26147063e-02 1.08552718e-02 9.30932394e-03 7.95925305e-03
#  6.78642384e-03 5.77220478e-03 4.89864227e-03 4.14887764e-03
#  3.50738057e-03 2.96005381e-03 2.49424987e-03 2.09872930e-03
#  1.76358241e-03 1.48012970e-03 1.24081214e-03 1.03907860e-03
#  8.69275648e-04 7.26542737e-04 6.06714908e-04 5.06233773e-04
#  4.22067255e-04 3.51637918e-04 2.92759559e-04 2.43581480e-04
#  2.02539828e-04 1.68315330e-04 1.39796732e-04 1.16049320e-04
#  9.62878964e-05 7.98536611e-05 6.61944875e-05 5.48481341e-05
#  4.54279913e-05 3.76110033e-05 3.11274528e-05 2.57523371e-05
#  2.12980978e-05 1.76085015e-05 1.45534969e-05 1.20248956e-05
#  9.93275187e-06 8.20232949e-06 6.77156345e-06 5.58893849e-06
# ...
