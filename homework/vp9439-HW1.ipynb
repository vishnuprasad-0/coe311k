# %%
import numpy as np
import matplotlib.pyplot as plt

samples = np.arange(10,1000,20)
error = np.zeros(len(n))
for i,num in enumerate(n):
    error[i] = np.abs(np.pi - monteCarlo(num))

plot()

# %%
def monteCarlo(n):
    x = np.random.rand(n)
    y = np.random.rand(n)
    z = x**2 + y**2
    z = z[z < 1]
    estPi = 4 * len(z) / n
    return estPi

# %%
def plot():
    plt.plot(n, error, 'b.')
    plt.xlabel("Number of Samples")
    plt.ylabel("Error")
    plt.show()
